# %%
import yfinance as yf

# download dataframe

# %%
import pandas as pd
with pd.ExcelWriter('stock_data1.xlsx', engine='xlsxwriter') as writer:
    # Write each dataframe to a different worksheet
    Page_Ind.to_excel(writer, sheet_name='Page_Ind')
    KPR_Mill.to_excel(writer, sheet_name='KPR_Mill')
    Trident.to_excel(writer, sheet_name='Trident')
    Welspun_Living.to_excel(writer, sheet_name='Welspun_Living')
    Swan_Energy.to_excel(writer, sheet_name='Swan_Energy')

print("Data saved to stock_data.xlsx with different worksheets.")
#
# Out:
# Data saved to stock_data.xlsx with different worksheets.

# %%
# Page_Industries
Page_Ind = yf.download("PAGEIND.NS", start="2019-01-01", end="2023-12-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Page_Ind["Page_Ind_Daily_Returns"] = Page_Ind["Close"].pct_change()
Page_Ind
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-01-01  25200.000000  25200.000000  24602.550781  24847.199219
# 2019-01-02  24790.000000  25111.000000  24330.000000  24591.150391
# 2019-01-03  24500.000000  24700.000000  23529.449219  23614.099609
# 2019-01-04  23800.000000  24000.000000  22532.599609  22663.000000
# 2019-01-07  22977.650391  23498.800781  21825.000000  21907.550781
# ...                  ...           ...           ...           ...
# 2023-12-22  37480.000000  37777.000000  37181.851562  37612.250000
# 2023-12-26  37870.000000  37870.000000  37400.000000  37564.750000
# 2023-12-27  37564.750000  37999.898438  37364.800781  37929.449219
# 2023-12-28  37929.449219  38677.601562  37861.101562  38564.898438
# 2023-12-29  38679.949219  38889.199219  38364.050781  38512.750000
#
#                Adj Close  Volume  Page_Ind_Daily_Returns
# Date
# 2019-01-01  23833.339844   33677                     NaN
# ...

# %%
# Calculate price differences
delta = Page_Ind['Close'].diff()

# Set up gains and losses
gains = delta.clip(lower=0)
losses = -1 * delta.clip(upper=0)

# Calculate average gains and losses over a 14-day period (common setting)
avg_gain = gains.ewm(com=14, min_periods=14).mean()
avg_loss = losses.ewm(com=14, min_periods=14).mean()

# Calculate the Relative Strength Index (RSI)
rsi = 100 - (100 / (1 + (avg_gain / avg_loss)))

# Add RSI to the DataFrame
Page_Ind['RSI'] = rsi

# %%
Page_Ind.head(20)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-01-01  25200.000000  25200.000000  24602.550781  24847.199219
# 2019-01-02  24790.000000  25111.000000  24330.000000  24591.150391
# 2019-01-03  24500.000000  24700.000000  23529.449219  23614.099609
# 2019-01-04  23800.000000  24000.000000  22532.599609  22663.000000
# 2019-01-07  22977.650391  23498.800781  21825.000000  21907.550781
# 2019-01-08  21970.000000  23175.000000  21601.199219  23021.599609
# 2019-01-09  23061.000000  23388.000000  22762.349609  23262.800781
# 2019-01-10  23300.000000  23399.000000  22900.000000  23176.349609
# 2019-01-11  23176.349609  23449.000000  22734.050781  23356.000000
# 2019-01-14  23191.000000  23899.000000  22960.449219  23817.750000
# 2019-01-15  24048.000000  24266.500000  23600.000000  23760.599609
# 2019-01-16  23725.500000  24023.900391  23110.000000  23361.199219
# 2019-01-17  23440.000000  23559.800781  23120.000000  23265.750000
# ...

# %%
## Computing Volatility
import numpy as np
# Compute the logarithmic returns using the Closing price
Page_Ind['Log_Ret'] = np.log(Page_Ind['Close'] / Page_Ind['Close'].shift(1))

# Compute Volatility using the pandas rolling standard deviation function
Page_Ind['Volatility'] = Page_Ind['Log_Ret'].rolling(window=14).std() * np.sqrt(14)
Page_Ind.head(30)

# Plot the NIFTY Price series and the Volatility
# hdfc[['Close', 'Volatility']].plot(kind = "line", subplots=True, color='blue',figsize=(8, 6))
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-01-01  25200.000000  25200.000000  24602.550781  24847.199219
# 2019-01-02  24790.000000  25111.000000  24330.000000  24591.150391
# 2019-01-03  24500.000000  24700.000000  23529.449219  23614.099609
# 2019-01-04  23800.000000  24000.000000  22532.599609  22663.000000
# 2019-01-07  22977.650391  23498.800781  21825.000000  21907.550781
# 2019-01-08  21970.000000  23175.000000  21601.199219  23021.599609
# 2019-01-09  23061.000000  23388.000000  22762.349609  23262.800781
# 2019-01-10  23300.000000  23399.000000  22900.000000  23176.349609
# 2019-01-11  23176.349609  23449.000000  22734.050781  23356.000000
# 2019-01-14  23191.000000  23899.000000  22960.449219  23817.750000
# 2019-01-15  24048.000000  24266.500000  23600.000000  23760.599609
# 2019-01-16  23725.500000  24023.900391  23110.000000  23361.199219
# 2019-01-17  23440.000000  23559.800781  23120.000000  23265.750000
# ...

# %%
# Calculate the 14-day simple moving average of the closing prices
Page_Ind["Moving_Average"] = Page_Ind['Close'].rolling(window=14).mean()

Page_Ind.head(30)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-01-01  25200.000000  25200.000000  24602.550781  24847.199219
# 2019-01-02  24790.000000  25111.000000  24330.000000  24591.150391
# 2019-01-03  24500.000000  24700.000000  23529.449219  23614.099609
# 2019-01-04  23800.000000  24000.000000  22532.599609  22663.000000
# 2019-01-07  22977.650391  23498.800781  21825.000000  21907.550781
# 2019-01-08  21970.000000  23175.000000  21601.199219  23021.599609
# 2019-01-09  23061.000000  23388.000000  22762.349609  23262.800781
# 2019-01-10  23300.000000  23399.000000  22900.000000  23176.349609
# 2019-01-11  23176.349609  23449.000000  22734.050781  23356.000000
# 2019-01-14  23191.000000  23899.000000  22960.449219  23817.750000
# 2019-01-15  24048.000000  24266.500000  23600.000000  23760.599609
# 2019-01-16  23725.500000  24023.900391  23110.000000  23361.199219
# 2019-01-17  23440.000000  23559.800781  23120.000000  23265.750000
# ...

# %%
#K.P.R Mill Limited
KPR_Mill = yf.download("KPRMILL.NS", start="2019-01-01", end="2023-12-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
KPR_Mill["KPR_Mill_Daily_Returns"] = KPR_Mill["Close"].pct_change()
KPR_Mill
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01  112.080002  112.790001  111.470001  112.050003  109.892433
# 2019-01-02  112.190002  112.190002  110.709999  111.070000  108.931305
# 2019-01-03  111.110001  112.949997  111.000000  111.300003  109.156876
# 2019-01-04  111.669998  111.820000  108.800003  109.260002  107.156158
# 2019-01-07  110.580002  110.580002  107.199997  107.720001  105.645798
# ...                ...         ...         ...         ...         ...
# 2023-12-22  842.650024  848.900024  817.849976  833.250000  833.250000
# 2023-12-26  833.250000  838.000000  820.000000  824.150024  824.150024
# 2023-12-27  823.000000  829.799988  816.250000  820.250000  820.250000
# 2023-12-28  820.250000  827.349976  815.599976  824.049988  824.049988
# 2023-12-29  826.000000  834.000000  816.000000  824.799988  824.799988
#
#             Volume  KPR_Mill_Daily_Returns
# Date
# 2019-01-01   26810                     NaN
# ...

# %%
# Calculate price differences
delta = KPR_Mill['Close'].diff()

# Set up gains and losses
gains = delta.clip(lower=0)
losses = -1 * delta.clip(upper=0)

# Calculate average gains and losses over a 14-day period (common setting)
avg_gain = gains.ewm(com=14, min_periods=14).mean()
avg_loss = losses.ewm(com=14, min_periods=14).mean()

# Calculate the Relative Strength Index (RSI)
rsi = 100 - (100 / (1 + (avg_gain / avg_loss)))

# Add RSI to the DataFrame
KPR_Mill['RSI'] = rsi

# %%
KPR_Mill.head(20)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01  112.080002  112.790001  111.470001  112.050003  109.892433
# 2019-01-02  112.190002  112.190002  110.709999  111.070000  108.931305
# 2019-01-03  111.110001  112.949997  111.000000  111.300003  109.156876
# 2019-01-04  111.669998  111.820000  108.800003  109.260002  107.156158
# 2019-01-07  110.580002  110.580002  107.199997  107.720001  105.645798
# 2019-01-08  107.800003  108.959999  106.599998  107.900002  105.822334
# 2019-01-09  108.169998  108.169998  106.750000  106.889999  104.831787
# 2019-01-10  107.019997  107.660004  106.309998  106.620003  104.566994
# 2019-01-11  106.349998  107.089996  104.419998  104.580002  102.566269
# 2019-01-14  104.800003  104.800003  102.239998  103.029999  101.046104
# 2019-01-15  103.209999  108.000000  103.209999  106.040001  103.998154
# 2019-01-16  107.000000  107.739998  106.000000  106.080002  104.037376
# ...

# %%
## Computing Volatility
import numpy as np
# Compute the logarithmic returns using the Closing price
KPR_Mill['Log_Ret'] = np.log(KPR_Mill['Close'] / KPR_Mill['Close'].shift(1))

# Compute Volatility using the pandas rolling standard deviation function
KPR_Mill['Volatility'] = KPR_Mill['Log_Ret'].rolling(window=14).std() * np.sqrt(14)
KPR_Mill.head(30)

# Plot the NIFTY Price series and the Volatility
# hdfc[['Close', 'Volatility']].plot(kind = "line", subplots=True, color='blue',figsize=(8, 6))
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01  112.080002  112.790001  111.470001  112.050003  109.892433
# 2019-01-02  112.190002  112.190002  110.709999  111.070000  108.931305
# 2019-01-03  111.110001  112.949997  111.000000  111.300003  109.156876
# 2019-01-04  111.669998  111.820000  108.800003  109.260002  107.156158
# 2019-01-07  110.580002  110.580002  107.199997  107.720001  105.645798
# 2019-01-08  107.800003  108.959999  106.599998  107.900002  105.822334
# 2019-01-09  108.169998  108.169998  106.750000  106.889999  104.831787
# 2019-01-10  107.019997  107.660004  106.309998  106.620003  104.566994
# 2019-01-11  106.349998  107.089996  104.419998  104.580002  102.566269
# 2019-01-14  104.800003  104.800003  102.239998  103.029999  101.046104
# 2019-01-15  103.209999  108.000000  103.209999  106.040001  103.998154
# 2019-01-16  107.000000  107.739998  106.000000  106.080002  104.037376
# ...

# %%
# Calculate the 14-day simple moving average of the closing prices
KPR_Mill["Moving_Average"] = KPR_Mill['Close'].rolling(window=14).mean()

KPR_Mill.head(30)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01  112.080002  112.790001  111.470001  112.050003  109.892433
# 2019-01-02  112.190002  112.190002  110.709999  111.070000  108.931305
# 2019-01-03  111.110001  112.949997  111.000000  111.300003  109.156876
# 2019-01-04  111.669998  111.820000  108.800003  109.260002  107.156158
# 2019-01-07  110.580002  110.580002  107.199997  107.720001  105.645798
# 2019-01-08  107.800003  108.959999  106.599998  107.900002  105.822334
# 2019-01-09  108.169998  108.169998  106.750000  106.889999  104.831787
# 2019-01-10  107.019997  107.660004  106.309998  106.620003  104.566994
# 2019-01-11  106.349998  107.089996  104.419998  104.580002  102.566269
# 2019-01-14  104.800003  104.800003  102.239998  103.029999  101.046104
# 2019-01-15  103.209999  108.000000  103.209999  106.040001  103.998154
# 2019-01-16  107.000000  107.739998  106.000000  106.080002  104.037376
# ...

# %%
# Trident
Trident = yf.download("TRIDENT.NS", start="2019-01-01", end="2023-12-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Trident["Trident_Daily_Returns"] = Trident["Close"].pct_change()
Trident
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2019-01-01   6.620000   6.895000   6.620000   6.820000   5.939979  13560030
# 2019-01-02   6.770000   6.840000   6.650000   6.745000   5.874656   4528870
# 2019-01-03   6.790000   6.850000   6.710000   6.730000   5.861592   5166720
# 2019-01-04   6.765000   6.790000   6.630000   6.675000   5.813689   3540830
# 2019-01-07   6.700000   6.800000   6.700000   6.725000   5.857237   3584990
# ...               ...        ...        ...        ...        ...       ...
# 2023-12-22  36.500000  36.650002  35.900002  36.150002  36.150002   7525883
# 2023-12-26  36.400002  36.450001  35.900002  36.049999  36.049999   7552200
# 2023-12-27  36.400002  36.400002  35.849998  36.099998  36.099998   7051280
# 2023-12-28  36.099998  36.200001  35.849998  35.900002  35.900002   5274318
# 2023-12-29  35.950001  36.450001  35.700001  36.299999  36.299999   8058888
#
#             Trident_Daily_Returns
# Date
# ...

# %%
# Calculate price differences
delta = Trident['Close'].diff()

# Set up gains and losses
gains = delta.clip(lower=0)
losses = -1 * delta.clip(upper=0)

# Calculate average gains and losses over a 14-day period (common setting)
avg_gain = gains.ewm(com=14, min_periods=14).mean()
avg_loss = losses.ewm(com=14, min_periods=14).mean()

# Calculate the Relative Strength Index (RSI)
rsi = 100 - (100 / (1 + (avg_gain / avg_loss)))

# Add RSI to the DataFrame
Trident['RSI'] = rsi

# %%
Trident.head(20)
# Out:
#              Open   High    Low  Close  Adj Close    Volume  \
# Date
# 2019-01-01  6.620  6.895  6.620  6.820   5.939979  13560030
# 2019-01-02  6.770  6.840  6.650  6.745   5.874656   4528870
# 2019-01-03  6.790  6.850  6.710  6.730   5.861592   5166720
# 2019-01-04  6.765  6.790  6.630  6.675   5.813689   3540830
# 2019-01-07  6.700  6.800  6.700  6.725   5.857237   3584990
# 2019-01-08  6.750  6.880  6.725  6.790   5.913850   5611110
# 2019-01-09  6.825  6.860  6.735  6.770   5.896431   2903480
# 2019-01-10  6.875  7.170  6.850  7.095   6.179494  32175270
# 2019-01-11  7.095  7.190  7.060  7.095   6.179494  11060100
# 2019-01-14  7.095  7.130  6.955  6.990   6.088043   6074530
# 2019-01-15  7.025  7.570  7.020  7.275   6.336268  80213560
# 2019-01-16  7.285  7.350  7.040  7.070   6.157720  17148720
# 2019-01-17  7.100  7.190  7.030  7.080   6.166429   9352690
# 2019-01-18  7.150  7.150  6.960  6.995   6.092398   5176140
# ...

# %%
## Computing Volatility
import numpy as np
# Compute the logarithmic returns using the Closing price
Trident['Log_Ret'] = np.log(Trident['Close'] / Trident['Close'].shift(1))

# Compute Volatility using the pandas rolling standard deviation function
Trident['Volatility'] = Trident['Log_Ret'].rolling(window=14).std() * np.sqrt(14)
Trident.head(30)

# Plot the NIFTY Price series and the Volatility
# hdfc[['Close', 'Volatility']].plot(kind = "line", subplots=True, color='blue',figsize=(8, 6))
# Out:
#              Open   High    Low  Close  Adj Close    Volume  \
# Date
# 2019-01-01  6.620  6.895  6.620  6.820   5.939979  13560030
# 2019-01-02  6.770  6.840  6.650  6.745   5.874656   4528870
# 2019-01-03  6.790  6.850  6.710  6.730   5.861592   5166720
# 2019-01-04  6.765  6.790  6.630  6.675   5.813689   3540830
# 2019-01-07  6.700  6.800  6.700  6.725   5.857237   3584990
# 2019-01-08  6.750  6.880  6.725  6.790   5.913850   5611110
# 2019-01-09  6.825  6.860  6.735  6.770   5.896431   2903480
# 2019-01-10  6.875  7.170  6.850  7.095   6.179494  32175270
# 2019-01-11  7.095  7.190  7.060  7.095   6.179494  11060100
# 2019-01-14  7.095  7.130  6.955  6.990   6.088043   6074530
# 2019-01-15  7.025  7.570  7.020  7.275   6.336268  80213560
# 2019-01-16  7.285  7.350  7.040  7.070   6.157720  17148720
# 2019-01-17  7.100  7.190  7.030  7.080   6.166429   9352690
# 2019-01-18  7.150  7.150  6.960  6.995   6.092398   5176140
# ...

# %%
# Calculate the 14-day simple moving average of the closing prices
Trident["Moving_Average"] = Trident['Close'].rolling(window=14).mean()

Trident.head(30)
# Out:
#              Open   High    Low  Close  Adj Close    Volume  \
# Date
# 2019-01-01  6.620  6.895  6.620  6.820   5.939979  13560030
# 2019-01-02  6.770  6.840  6.650  6.745   5.874656   4528870
# 2019-01-03  6.790  6.850  6.710  6.730   5.861592   5166720
# 2019-01-04  6.765  6.790  6.630  6.675   5.813689   3540830
# 2019-01-07  6.700  6.800  6.700  6.725   5.857237   3584990
# 2019-01-08  6.750  6.880  6.725  6.790   5.913850   5611110
# 2019-01-09  6.825  6.860  6.735  6.770   5.896431   2903480
# 2019-01-10  6.875  7.170  6.850  7.095   6.179494  32175270
# 2019-01-11  7.095  7.190  7.060  7.095   6.179494  11060100
# 2019-01-14  7.095  7.130  6.955  6.990   6.088043   6074530
# 2019-01-15  7.025  7.570  7.020  7.275   6.336268  80213560
# 2019-01-16  7.285  7.350  7.040  7.070   6.157720  17148720
# 2019-01-17  7.100  7.190  7.030  7.080   6.166429   9352690
# 2019-01-18  7.150  7.150  6.960  6.995   6.092398   5176140
# ...

# %%
# Welspun Living
Welspun_Living = yf.download("WELSPUNLIV.NS", start="2019-01-01", end="2023-12-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Welspun_Living["Welspun_Living_Daily_Returns"] = Welspun_Living["Close"].pct_change()
Welspun_Living
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01   59.799999   60.750000   59.299999   60.500000   57.771790
# 2019-01-02   60.450001   62.400002   59.750000   61.349998   58.583466
# 2019-01-03   61.700001   62.250000   60.799999   61.200001   58.440231
# 2019-01-04   61.200001   61.599998   60.250000   60.849998   58.106010
# 2019-01-07   61.049999   61.799999   61.000000   61.299999   58.535717
# ...                ...         ...         ...         ...         ...
# 2023-12-22  146.449997  147.800003  142.500000  145.300003  145.300003
# 2023-12-26  145.300003  146.949997  144.000000  144.250000  144.250000
# 2023-12-27  144.000000  146.750000  142.199997  143.449997  143.449997
# 2023-12-28  144.000000  146.600006  140.949997  142.050003  142.050003
# 2023-12-29  143.449997  145.399994  140.050003  144.449997  144.449997
#
#              Volume  Welspun_Living_Daily_Returns
# Date
# 2019-01-01   377138                           NaN
# ...

# %%
# Calculate price differences
delta = Welspun_Living['Close'].diff()

# Set up gains and losses
gains = delta.clip(lower=0)
losses = -1 * delta.clip(upper=0)

# Calculate average gains and losses over a 14-day period (common setting)
avg_gain = gains.ewm(com=14, min_periods=14).mean()
avg_loss = losses.ewm(com=14, min_periods=14).mean()

# Calculate the Relative Strength Index (RSI)
rsi = 100 - (100 / (1 + (avg_gain / avg_loss)))

# Add RSI to the DataFrame
Welspun_Living['RSI'] = rsi

# %%
Welspun_Living.head(20)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2019-01-01  59.799999  60.750000  59.299999  60.500000  57.771790   377138
# 2019-01-02  60.450001  62.400002  59.750000  61.349998  58.583466   782890
# 2019-01-03  61.700001  62.250000  60.799999  61.200001  58.440231   398033
# 2019-01-04  61.200001  61.599998  60.250000  60.849998  58.106010   369574
# 2019-01-07  61.049999  61.799999  61.000000  61.299999  58.535717   252967
# 2019-01-08  61.200001  61.900002  60.750000  61.250000  58.487976   321598
# 2019-01-09  61.099998  61.799999  60.549999  61.250000  58.487976   422659
# 2019-01-10  61.099998  61.900002  61.000000  61.549999  58.774448   255807
# 2019-01-11  61.700001  65.000000  61.250000  62.150002  59.347389  1062571
# 2019-01-14  62.200001  62.500000  61.200001  61.500000  58.726696   290487
# 2019-01-15  62.150002  63.049999  61.400002  62.599998  59.777096   419450
# ...

# %%
## Computing Volatility
import numpy as np
# Compute the logarithmic returns using the Closing price
Welspun_Living['Log_Ret'] = np.log(Welspun_Living['Close'] / Trident['Close'].shift(1))

# Compute Volatility using the pandas rolling standard deviation function
Welspun_Living['Volatility'] = Welspun_Living['Log_Ret'].rolling(window=14).std() * np.sqrt(14)
Welspun_Living.head(30)

# Plot the NIFTY Price series and the Volatility
# hdfc[['Close', 'Volatility']].plot(kind = "line", subplots=True, color='blue',figsize=(8, 6))
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2019-01-01  59.799999  60.750000  59.299999  60.500000  57.771790   377138
# 2019-01-02  60.450001  62.400002  59.750000  61.349998  58.583466   782890
# 2019-01-03  61.700001  62.250000  60.799999  61.200001  58.440231   398033
# 2019-01-04  61.200001  61.599998  60.250000  60.849998  58.106010   369574
# 2019-01-07  61.049999  61.799999  61.000000  61.299999  58.535717   252967
# 2019-01-08  61.200001  61.900002  60.750000  61.250000  58.487976   321598
# 2019-01-09  61.099998  61.799999  60.549999  61.250000  58.487976   422659
# 2019-01-10  61.099998  61.900002  61.000000  61.549999  58.774448   255807
# 2019-01-11  61.700001  65.000000  61.250000  62.150002  59.347389  1062571
# 2019-01-14  62.200001  62.500000  61.200001  61.500000  58.726696   290487
# 2019-01-15  62.150002  63.049999  61.400002  62.599998  59.777096   419450
# ...

# %%
# Calculate the 14-day simple moving average of the closing prices
Welspun_Living["Moving_Average"] = Welspun_Living['Close'].rolling(window=14).mean()

Welspun_Living.head(30)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2019-01-01  59.799999  60.750000  59.299999  60.500000  57.771790   377138
# 2019-01-02  60.450001  62.400002  59.750000  61.349998  58.583466   782890
# 2019-01-03  61.700001  62.250000  60.799999  61.200001  58.440231   398033
# 2019-01-04  61.200001  61.599998  60.250000  60.849998  58.106010   369574
# 2019-01-07  61.049999  61.799999  61.000000  61.299999  58.535717   252967
# 2019-01-08  61.200001  61.900002  60.750000  61.250000  58.487976   321598
# 2019-01-09  61.099998  61.799999  60.549999  61.250000  58.487976   422659
# 2019-01-10  61.099998  61.900002  61.000000  61.549999  58.774448   255807
# 2019-01-11  61.700001  65.000000  61.250000  62.150002  59.347389  1062571
# 2019-01-14  62.200001  62.500000  61.200001  61.500000  58.726696   290487
# 2019-01-15  62.150002  63.049999  61.400002  62.599998  59.777096   419450
# ...

# %%
# Swan Energy
Swan_Energy = yf.download("SWANENERGY.NS", start="2019-01-01", end="2023-12-31")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Swan_Energy["Swan_Energy_Daily_Returns"] = Swan_Energy["Close"].pct_change()
Swan_Energy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01  101.699997  102.300003   99.500000  100.099998   99.774803
# 2019-01-02  100.199997  100.900002   97.000000   97.699997   97.382591
# 2019-01-03   98.250000   99.500000   97.849998   98.800003   98.479034
# 2019-01-04   98.800003  101.000000   98.000000   99.449997   99.126907
# 2019-01-07  100.699997  100.699997   98.050003   98.900002   98.578697
# ...                ...         ...         ...         ...         ...
# 2023-12-22  502.000000  512.900024  494.000000  506.399994  506.399994
# 2023-12-26  511.500000  518.200012  498.600006  503.350006  503.350006
# 2023-12-27  504.399994  514.000000  498.600006  508.750000  508.750000
# 2023-12-28  507.000000  515.799988  500.700012  512.849976  512.849976
# 2023-12-29  520.000000  525.299988  505.149994  511.000000  511.000000
#
#               Volume  Swan_Energy_Daily_Returns
# Date
# 2019-01-01    267114                        NaN
# ...

# %%
# Calculate price differences
delta = Swan_Energy['Close'].diff()

# Set up gains and losses
gains = delta.clip(lower=0)
losses = -1 * delta.clip(upper=0)

# Calculate average gains and losses over a 14-day period (common setting)
avg_gain = gains.ewm(com=14, min_periods=14).mean()
avg_loss = losses.ewm(com=14, min_periods=14).mean()

# Calculate the Relative Strength Index (RSI)
rsi = 100 - (100 / (1 + (avg_gain / avg_loss)))

# Add RSI to the DataFrame
Swan_Energy['RSI'] = rsi

# %%
Swan_Energy.head(20)
# Out:
#                   Open        High        Low       Close   Adj Close  Volume  \
# Date
# 2019-01-01  101.699997  102.300003  99.500000  100.099998   99.774803  267114
# 2019-01-02  100.199997  100.900002  97.000000   97.699997   97.382591  326180
# 2019-01-03   98.250000   99.500000  97.849998   98.800003   98.479034  215418
# 2019-01-04   98.800003  101.000000  98.000000   99.449997   99.126907  219293
# 2019-01-07  100.699997  100.699997  98.050003   98.900002   98.578697  324370
# 2019-01-08   99.699997   99.699997  98.099998   98.349998   98.030487  192394
# 2019-01-09   99.000000   99.000000  98.000000   98.300003   97.980652  429586
# 2019-01-10   99.300003  101.800003  97.400002   99.599998   99.276428  227875
# 2019-01-11   99.599998  101.449997  99.599998  100.500000  100.173508  303237
# 2019-01-14  102.400002  102.400002  99.599998  100.000000   99.675133  202494
# 2019-01-15  101.000000  101.000000  99.000000   99.900002   99.575462  274422
# ...

# %%
## Computing Volatility
import numpy as np
# Compute the logarithmic returns using the Closing price
Swan_Energy['Log_Ret'] = np.log(Swan_Energy['Close'] / Swan_Energy['Close'].shift(1))

# Compute Volatility using the pandas rolling standard deviation function
Swan_Energy['Volatility'] = Swan_Energy['Log_Ret'].rolling(window=14).std() * np.sqrt(14)
Swan_Energy.head(30)

# Plot the NIFTY Price series and the Volatility
# hdfc[['Close', 'Volatility']].plot(kind = "line", subplots=True, color='blue',figsize=(8, 6))
# Out:
#                   Open        High        Low       Close   Adj Close  Volume  \
# Date
# 2019-01-01  101.699997  102.300003  99.500000  100.099998   99.774803  267114
# 2019-01-02  100.199997  100.900002  97.000000   97.699997   97.382591  326180
# 2019-01-03   98.250000   99.500000  97.849998   98.800003   98.479034  215418
# 2019-01-04   98.800003  101.000000  98.000000   99.449997   99.126907  219293
# 2019-01-07  100.699997  100.699997  98.050003   98.900002   98.578697  324370
# 2019-01-08   99.699997   99.699997  98.099998   98.349998   98.030487  192394
# 2019-01-09   99.000000   99.000000  98.000000   98.300003   97.980652  429586
# 2019-01-10   99.300003  101.800003  97.400002   99.599998   99.276428  227875
# 2019-01-11   99.599998  101.449997  99.599998  100.500000  100.173508  303237
# 2019-01-14  102.400002  102.400002  99.599998  100.000000   99.675133  202494
# 2019-01-15  101.000000  101.000000  99.000000   99.900002   99.575462  274422
# ...

# %%
# Calculate the 14-day simple moving average of the closing prices
Swan_Energy["Moving_Average"] = Swan_Energy['Close'].rolling(window=14).mean()

Swan_Energy.head(30)
# Out:
#                   Open        High        Low       Close   Adj Close  Volume  \
# Date
# 2019-01-01  101.699997  102.300003  99.500000  100.099998   99.774803  267114
# 2019-01-02  100.199997  100.900002  97.000000   97.699997   97.382591  326180
# 2019-01-03   98.250000   99.500000  97.849998   98.800003   98.479034  215418
# 2019-01-04   98.800003  101.000000  98.000000   99.449997   99.126907  219293
# 2019-01-07  100.699997  100.699997  98.050003   98.900002   98.578697  324370
# 2019-01-08   99.699997   99.699997  98.099998   98.349998   98.030487  192394
# 2019-01-09   99.000000   99.000000  98.000000   98.300003   97.980652  429586
# 2019-01-10   99.300003  101.800003  97.400002   99.599998   99.276428  227875
# 2019-01-11   99.599998  101.449997  99.599998  100.500000  100.173508  303237
# 2019-01-14  102.400002  102.400002  99.599998  100.000000   99.675133  202494
# 2019-01-15  101.000000  101.000000  99.000000   99.900002   99.575462  274422
# ...
